# %%
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("../data/datasets/abs_topics_filt_july.pkl")
# Out:
# /usr/local/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module multiprocessing was already imported from /usr/local/Cellar/python/2.7.3/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/__init__.pyc, but /usr/local/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
from IPython.html import widgets
# %load_ext rmagic
# %matplotlib inline

# %%
import numpy as np
from base import plotting
from base.classifiers import OnevsallClassifier, PairwiseClassifier
import base.classifiers.pairwise as pw
import base.classifiers.onevsall as oa
import glob
import pandas as pd
from ggplot import *
from base import tools
from scipy import stats
import itertools
import seaborn as sns
import mpld3
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pylab
import base.classifiers.pairwise as mc

# %%
mpld3.enable_notebook()

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(MASS)
# library(reshape2)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %% [markdown]
# # Active or not - hard zero

# %%
clfs = [OnevsallClassifier.load(clf + "/classifier.pkl") for clf in glob.glob("../results/ward*30*OvA*50*")]

# %%
plot_score = []
all_scores = []
for clfs in [clfs]:
    for clf in clfs:
        for n, score in enumerate(clf.class_score):
            all_scores.append([clf.mask_num, n, clf.thresh, 'clf' , score, oa.average_ns(clf, mean=False)[n][0]/(oa.average_ns(clf,mean=False)[n][1]*1.0), oa.average_ns(clf, mean=False)[n][0]])
        plot_score.append([clf.mask_num, clf.thresh, 'clf' , clf.class_score.mean(), oa.average_ns(clf)[0]/(oa.average_ns(clf)[1]*1.0), oa.average_ns(clf)[0]])
        plot_score.append([clf.mask_num, clf.thresh, 'dummy', clf.dummy_score.mean(), 0, 0])

# %%
plot_score = pd.DataFrame(plot_score, columns=['n_regions', 'threshold', 'clf', 'roc_auc', 'ratio', 'n' ])
plot_score['n_regions'] = plot_score['n_regions'].apply(str)

all_scores = pd.DataFrame(all_scores, columns=['n_regions', 'region', 'threshold', 'clf', 'roc_auc', 'ratio', 'n' ])
all_scores['n_regions'] = all_scores['n_regions'].apply(str)

# %%
from base.tools import region_n_vox
n_vox = []
for regions in clfs:
    n_vox = n_vox + list(itertools.izip(itertools.repeat(regions.mask_num), range(0, regions.mask_num), 
                                     list(region_n_vox(dataset, regions.mask_img))))
n_vox = pd.DataFrame(n_vox, columns=['n_regions', 'region', 'voxels'])
n_vox['n_regions'] = n_vox['n_regions'].apply(str)

# %%
all_scores = pd.merge(all_scores, n_vox)
# %Rpush all_scores

# %%
# %%R -w 1000 -h 400
# ggplot(all_scores, aes(n_regions, roc_auc, group=n_regions,color=factor(n_regions))) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() +
# theme(legend.position='none') + xlab("Number of regions") + ylab("Discriminability (area under ROC)") + facet_grid(.~threshold)

# %%
all_scores.to_csv("all_scores.csv", index=False)

# %%
# %%R -w 600 -h 400
# ggplot(all_scores, aes(threshold, roc_auc, color=n_regions)) + stat_summary(fun.y=mean, geom='line', size=3, alpha = 0.8) + stat_summary(fun.y=mean, geom='point', size=5, alpha = 0.8) +
# coord_cartesian(ylim = c(0.5, 0.65)) + theme_bw() + xlab("Activation threshold (voxels)") + ylab("Discriminability (area under ROC)") + scale_colour_discrete(name = "Regions (n)")

# %%
# %%R -w 600 -h 400
# ggplot(all_scores, aes(threshold, n, color=n_regions)) + stat_summary(fun.y=mean, geom='line', size=3, alpha = 0.8) + stat_summary(fun.y=mean, geom='point', size=5, alpha = 0.8) +
#  theme_bw() + xlab("Activation threshold (voxels)") + ylab("N") + scale_colour_discrete(name = "Regions (n)")

# %%
# %%R -w 1000
# ggplot(all_scores, aes(n_regions, n, group=n_regions,color=n_regions)) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() + facet_grid(.~threshold)

# %%
## Get threshold which resulted in max roc_auc for that region
max_thresh = all_scores.groupby(['n_regions', 'threshold']).agg(np.mean).sort('roc_auc', ascending=False).reset_index().groupby('n_regions',  as_index=False).first()

# %%
max_thresh.ix[:, 0:2]
# Out:
#   n_regions  threshold
# 0        30         50
#
# [1 rows x 2 columns]

# %%
max_scores = pd.merge(all_scores, max_thresh.ix[:, 0:2])
# %Rpush max_scores
max_scores.to_csv("max_scores.csv", index=False)

# %%
# %%R -w 450 -h 400
# ggplot(max_scores, aes(n_regions, roc_auc, group=n_regions,color=factor(n_regions))) + geom_point(position=position_jitter(width=0.015), alpha = 0.8) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() +
# theme(legend.position='none') + xlab("Number of regions") + ylab("Discriminability (area under ROC)")

# %%
# %%R -w 450 -h 400
# ggplot(max_scores, aes(n_regions, n, group=n_regions,color=factor(n_regions))) + geom_point(position=position_jitter(width=0.015), alpha = 0.8) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() +
# theme(legend.position='none') + xlab("Number of regions") + ylab("N")

# %%
max_scores.groupby('n_regions').describe()
# Out:
#                     region  threshold    roc_auc      ratio            n  \
# n_regions
# 30        count  90.000000         90  90.000000  90.000000    90.000000
#           mean   14.500000         50   0.592351   1.108477  3724.966667
#           std     8.703932          0   0.039638   1.000599  1272.210696
#           min     0.000000         50   0.501233   0.270249  1745.000000
#           25%     7.000000         50   0.563868   0.543756  2884.000000
#           50%    14.500000         50   0.598759   0.818035  3600.000000
#           75%    22.000000         50   0.623214   1.060347  4217.000000
#           max    29.000000         50   0.651291   4.461939  6858.000000
#
#                        voxels
# n_regions
# 30        count     90.000000
#           mean    7615.100000
#           std     9239.424502
#           min      625.000000
#           25%     2156.000000
#           50%     4279.500000
#           75%     8157.000000
#           max    34160.000000
#
# ...

# %%
all_scores[all_scores['n_regions'] == '30'].describe()
# Out:
#            region   threshold     roc_auc       ratio            n  \
# count  270.000000  270.000000  270.000000  270.000000   270.000000
# mean    14.500000  150.000000    0.581789    0.738629  2363.855556
# std      8.671515   81.801282    0.047956    0.852506  1525.125836
# min      0.000000   50.000000    0.499813    0.017628   107.000000
# 25%      7.000000   50.000000    0.541970    0.231174  1142.000000
# 50%     14.500000  150.000000    0.581339    0.482261  1970.500000
# 75%     22.000000  250.000000    0.621837    0.872033  3480.000000
# max     29.000000  250.000000    0.685791    4.461939  6858.000000
#
#              voxels
# count    270.000000
# mean    7615.100000
# std     9205.013118
# min      625.000000
# 25%     2156.000000
# 50%     4279.500000
# 75%     8157.000000
# max    34160.000000
#
# [8 rows x 6 columns]

# %%
max_scores[max_scores['n_regions'] == '30']
# Out:
#    n_regions  region  threshold  clf   roc_auc     ratio     n  voxels
# 0         30       0         50  clf  0.638308  0.876018  3766    5121
# 1         30       0         50  clf  0.638308  0.876018  3766    5121
# 2         30       0         50  clf  0.638308  0.876018  3766    5121
# 3         30       1         50  clf  0.617882  0.872033  4041    8157
# 4         30       1         50  clf  0.617882  0.872033  4041    8157
# 5         30       1         50  clf  0.617882  0.872033  4041    8157
# 6         30       2         50  clf  0.609142  0.742951  3399    2000
# 7         30       2         50  clf  0.609142  0.742951  3399    2000
# 8         30       2         50  clf  0.609142  0.742951  3399    2000
# 9         30       3         50  clf  0.623214  0.583806  2884    1819
# 10        30       3         50  clf  0.623214  0.583806  2884    1819
# 11        30       3         50  clf  0.623214  0.583806  2884    1819
# ...

# %%
# %%R -w 1100 -h 400 -u px
# ggplot(all_scores, aes(voxels, n, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F) + facet_grid(.~n_regions)

# %%
# %%R -w 1100 -h 400 -u px
# ggplot(max_scores, aes(voxels, n, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F)

# %%
# %%R -w 1100 -h 400 -u px
# ggplot(all_scores, aes(n, roc_auc, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F) + facet_grid(.~n_regions)

# %%
# %%R -w 1100 -h 400 -u px
# ggplot(max_scores, aes(n, roc_auc, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F) + facet_grid(.~n_regions)

# %%
stats.pearsonr(all_scores[all_scores.n_regions == '10'].n, all_scores[all_scores.n_regions == '10'].roc_auc)
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# (nan, nan)

# %%
# %%R -w 1000 -h 480 -u px
# ggplot(all_scores, aes(voxels, roc_auc, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F) + facet_grid(.~n_regions)

# %%
# %%R -w 1000 -h 480 -u px
# ggplot(max_scores, aes(voxels, roc_auc, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F) + facet_grid(.~n_regions)

# %%
o_clf = [clf for clf in clfs if (clf.mask_num == 30) & (clf.thresh == 50)][0]

# %%
o_clf.class_score.mean()
# Out:
# 0.59235086286728422

# %%
tools.make_mask_map(o_clf.class_score, o_clf.mask_img, '../results/ward_30_OvA_RidgeClassifier_DM_hard0_roc_abs_topics_filt_tn_50')

# %%
max_scores.roc_auc.mean()
# Out:
# 0.59235086286728422

# %%
o_clf.class_score.mean()
# Out:
# 0.59235086286728422

# %% [markdown]
# ### Discriminability by base rate

# %%
# Set region and classifier for following analyses
base_rates = tools.region_vox_baserates(dataset, '../masks/ward/30.nii.gz')

# %%
base_rates.columns = ['region', 'base_rate']
acc = all_scores[(all_scores['threshold'] == 50) & (all_scores['n_regions'] == '30')].copy()

acc['region'] = acc['region'] + 1
pl = pd.merge(base_rates, acc)
# %Rpush pl

# %%
mean_br = pl.groupby(['region']).agg(np.mean).reset_index()
mean_br_plot = mean_br.rename(columns = {'base_rate':'Activation base rate (% studies active)', 'roc_auc': "Discriminability (area under ROC)"})
br_auc_oplot = sns.lmplot('Activation base rate (% studies active)', 'Discriminability (area under ROC)', mean_br_plot, ci=None)
tooltip = mpld3.plugins.PointLabelTooltip(br_auc_oplot.axes[0][0].collections[0], labels=list(mean_br.region))
fig = plt.gcf()
mpld3.plugins.connect(fig, tooltip)
# %Rpush mean_br

# %%
mean_br.region.max()
# Out:
# 30.0

# %%
stats.pearsonr(mean_br.roc_auc, mean_br.base_rate)
# Out:
# (0.070113473061820974, 0.71275169540774508)

# %% [markdown]
# High base rate, low ROC_AUC regions:
#     - 13 - insula
#     - 9 - pre-SMA
#     - 14 - anterior MFG
#     - 19- mPFC
#
# Low base rate, high roc_auc
#     - 10 - visual cortex
#     - 15 - motor
#     - 27 - mPFC/Orbital cluster
#
# Low BR, low roc_auc
#     - 18 - Sprawly
#     - 6 - Thalamus
#     - 1 - Another sprawly mpfc like region

# %%
# %R print(summary(lm(roc_auc~base_rate, data=mean_br)))
# Out:
# Call:
# lm(formula = roc_auc ~ base_rate, data = mean_br)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.091833 -0.024017  0.007549  0.030242  0.058824
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.58584    0.01901  30.823   <2e-16 ***
# base_rate    0.30123    0.80994   0.372    0.713
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0407 on 28 degrees of freedom
# Multiple R-squared:  0.004916,	Adjusted R-squared:  -0.03062
# F-statistic: 0.1383 on 1 and 28 DF,  p-value: 0.7128

# %% [markdown]
# ## Feature importance analysis

# %%
# o_clf = clfs_30[0]
# def oa_plot_wrap(**kwargs):
#     oa.region_heatmap(o_clf, **kwargs)
# widgets.interact(oa_plot_wrap, zscore_regions=True, zscore_features=False, thresh=widgets.FloatSliderWidget(min=0.000001, max=4, step=0.01, value=1))

# %% [markdown]
# What are the top features overall?

# %%
mean_fis = pd.DataFrame(np.array([np.round(o_clf.feature_importances.mean(axis=0), 3), o_clf.feature_names]).T, columns=['mean_fi', 'topic_name'])

# %%
word_keys = pd.read_csv("../data/unprocessed/abstract_topics_filtered/top_words_80-july.csv")

# %%
mean_fis = pd.merge(mean_fis, word_keys)

# %%
# print mean_fis.sort('mean_fi', ascending=False).values

# %%
# The mean of the feature importances predicts the classification score
stats.pearsonr(o_clf.feature_importances.mean(axis=1), o_clf.class_score)
# Out:
# (-0.0090056427056930208, 0.96232924081926197)

# %%
# The variance of the feature importances predicts the classification score
stats.pearsonr(o_clf.feature_importances.var(axis=1), o_clf.class_score)
# Out:
# (0.95589827270464456, 1.9676228222259102e-16)

# %%
o_fi = pd.DataFrame(o_clf.feature_importances)

# Melt feature importances, and add top_words for each feeature
o_fi['region'] = range(1, o_fi.shape[0] + 1)
o_fis_melt = pd.melt(o_fi, var_name='topic_order', value_name='importance', id_vars=['region'])

top_words = pd.read_csv("../data/unprocessed/abstract_topics_filtered/top_words_80-july.csv")
keys = pd.merge(pd.DataFrame(np.array([range(0, 80), o_clf.feature_names]).T, columns=['topic_order', 'topic_name']), top_words)
keys.topic_order = keys.topic_order.astype('int')

o_fis_melt= pd.merge(o_fis_melt, keys)
o_fis_melt['abs_imp'] = np.abs(o_fis_melt['importance'])

o_fis_melt = pd.merge(o_fis_melt, mean_br)
# %Rpush o_fis_melt

# %%
o_fis_melt.region.min()
# Out:
# 1

# %%
o_fis_melt.roc_auc.max()
# Out:
# 0.65129111474833479

# %%
(1/ (.6512-.5)) * (.55 - .5)
# Out:
# 0.330687830687831

# %%
o_fis_melt[o_fis_melt.region == 16].sort('abs_imp', ascending=False)
# Out:
#       region  topic_order  importance topic_name  \
# 1240      16           40    0.145228    topic45
# 1259      16           59    0.049670    topic62
# 1209      16            9   -0.048925    topic17
# 1268      16           68    0.044917    topic70
# 1217      16           17   -0.043897    topic24
# 1212      16           12   -0.041816     topic2
# 1233      16           33    0.041718    topic39
# 1265      16           65   -0.040404    topic68
# 1230      16           30   -0.039929    topic36
# 1238      16           38    0.037997    topic43
# 1253      16           53    0.037981    topic57
# 1242      16           42   -0.034219    topic47
# 1252      16           52   -0.032939    topic56
# 1241      16           41   -0.029739    topic46
# 1203      16            3    0.028853    topic11
# 1249      16           49   -0.028738    topic53
# 1250      16           50   -0.027734    topic54
# 1243      16           43   -0.026882    topic48
# ...

# %%
categories = np.unique(o_fis_melt['topic_name'])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))
o_fis_melt["Color"] = o_fis_melt['topic_name'].apply(lambda x: colordict[x])

pylab.rcParams['figure.figsize'] = 10, 5  # that's default image size for this interactive session
sns.set_style("white")
scatter = plt.scatter(o_fis_melt.roc_auc, o_fis_melt.importance, c=o_fis_melt.Color, cmap=cm.Set1, s=50, alpha=0.8)
fig = plt.gcf()
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=list(zip(o_fis_melt.region.values, o_fis_melt.top_words.values)))
mpld3.plugins.connect(fig, tooltip)

# %%
o_fis_melt.to_csv("o_fis_melt.csv", index=False)

# %%
# %%R -w 1000 -h 700
# library(colorRamps)
# library(RColorBrewer)
# getPalette = colorRampPalette(brewer.pal(9, "Set1"))
#
#
# ggplot(o_fis_melt, aes(roc_auc, importance, color=factor(topic_name))) +
# geom_abline(intercept = 0, slope = 0) + geom_point(position=position_jitter(width=.0005), size=2) +
# stat_summary(fun.y=mean, size=5, geom='point')+
# stat_summary(fun.y=mean, size=5, geom='point', color='black', shape=1, alpha=0.5) + theme_bw() + theme(legend.position='none') +
# scale_color_manual(values = getPalette(80)) + xlab ("Discriminability (area under ROC)") + ylab("Topic prediction weight") +
# theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(), panel.border = element_blank(),
#      axis.title.x = element_text(size=15), axis.title.y = element_text(size=15), axis.text.x = element_text(size=13), axis.text.y = element_text(size=13))

# %% [markdown]
# 12 - bilateral middle LPFC - sentences, language, reading, memory, cogntive control, wm
# 14 - IFJ - language memory cognitive
# 21- Anterior DLPFC
# 26 - vmpfc - social, reward, network
# 27 - mPFC - pain, emotion

# %%
o_fis_melt.sort(['roc_auc', 'abs_imp'], ascending=False).groupby('region').head()
# Out:
#              region  topic_order  importance topic_name  \
# region
# 14     1089      14           49    0.098488    topic53
#        1105      14           65    0.095532    topic68
#        1111      14           71    0.090470    topic73
#        1094      14           54   -0.083318    topic58
#        1116      14           76   -0.074243    topic78
# 23     1793      23           33    0.119758    topic39
#        1809      23           49    0.099614    topic53
#        1825      23           65    0.098264    topic68
#        1831      23           71    0.081791    topic73
#        1836      23           76   -0.076826    topic78
# 1      14         1           14    0.112462    topic21
#        44         1           44    0.106111    topic49
#        70         1           70    0.098755    topic72
#        76         1           76   -0.073927    topic78
#        48         1           48    0.073403    topic52
# 30     2362      30           42    0.082370    topic47
# ...

# %%
o_fi_acc_sum = o_fis_melt.groupby('region').agg(np.mean)

# %%
o_fi_acc_sum = o_fi_acc_sum.reset_index()

# %%
o_fi_acc_sum.sort

# %%
mean_imp_auc_p = sns.lmplot('roc_auc', 'abs_imp', o_fi_acc_sum, ci=None)
tooltip = mpld3.plugins.PointLabelTooltip(mean_imp_auc_p.axes[0][0].collections[0], labels=list(o_fi_acc_sum.region))
fig = plt.gcf()
mpld3.plugins.connect(fig, tooltip)
# %Rpush mean_br

# %%
stats.pearsonr(o_fi_acc_sum.importance, o_fi_acc_sum.roc_auc)
# Out:
# (-0.084811561407814151, 0.66180403561973999)

# %%
stats.pearsonr(o_fi_acc_sum.abs_imp, o_fi_acc_sum.roc_auc)
# Out:
# (0.93469320410056855, 1.2040066361507983e-13)

# %%
# sns.corrplot(o_clf.feature_importances.T, sig_stars=False, sig_corr=False, annot=False)

# %%
o_clf_mean_corr = np.corrcoef(o_clf.feature_importances).mean(axis=0)

# %%
stats.pearsonr(o_clf_mean_corr, o_clf.class_score)
# Out:
# (0.064462386384759318, 0.73504324851683012)

# %% [markdown]
# # Pairwise analysis

# %%
p_30 = [PairwiseClassifier.load(clf + "/classifier.pkl") for clf in glob.glob("../results/ward*Pairwise_RidgeClassifier_roc_DM_abs_topics_filt_tn*")]

# %%
p_clf = PairwiseClassifier.load(glob.glob("../results/ward_30_Pairwise_RidgeClassifier_roc_DM_abs_topics_filt_tn_50/")[0] + "/classifier.pkl")

# %%
p_clf.class_score = tools.copy_along_diagonal(p_clf.class_score)
p_clf.feature_importances = tools.copy_along_diagonal(p_clf.feature_importances, inverse=True)

# %%
pair_score = []
for clfs in [p_30]:
    for clf in clfs:
        for n, score in enumerate(clf.class_score.mean(axis=0)):
            pair_score.append([n, clf.mask_num, clf.thresh, 'clf' , score, pw.average_ns(clf, result='ratio').mean(axis=0)[n], pw.average_ns(clf, result='mean').mean(axis=0)[n]])
            
pair_score = pd.DataFrame(pair_score, columns=['region', 'n_regions', 'threshold', 'clf', 'roc_auc', 'ratio', 'n' ])
pair_score['n_regions'] = pair_score['n_regions'].apply(str)
pair_score = pd.merge(pair_score, n_vox)
# %Rpush pair_score

# %%
# %%R -w 550 -h 350
# ggplot(pair_score, aes(threshold, roc_auc, group=n_regions,color=factor(threshold))) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() + theme(legend.position='none')

# %%
# PLOT Acc vs coactivation

# %%
# %%R -w 550 -h 350
# ggplot(pair_score, aes(threshold, ratio, group=n_regions,color=factor(threshold))) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() + theme(legend.position='none')

# %%
# %%R -w 550 -h 350
# ggplot(pair_score, aes(threshold, n, color=factor(threshold))) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() + theme(legend.position='none')

# %%
# %%R -w 1000 -h 300
# ggplot(pair_score, aes(n, roc_auc)) + geom_point() + stat_smooth(method=lm) + theme_bw() + facet_grid(.~threshold)

# %%
# %%R -w 500 -h 480 -u px
# ggplot(pair_score, aes(voxels, n, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F)

# %%
# %%R -w 500 -h 480 -u px
# ggplot(pair_score, aes(voxels, roc_auc, color=factor(threshold))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F)

# %% [markdown]
# ## Discriminability by base rate

# %%
base_rates = tools.region_vox_baserates(dataset, '../masks/ward/30.nii.gz')

# %%
acc = pd.DataFrame([np.array(p_clf.class_score.mean(axis=0)), range(1, p_clf.mask_num + 1)]).T
acc.columns = ['roc_auc', 'region']
pl_p = pd.merge(base_rates, acc)
# %Rpush pl_p

# %%
# %%R
# data_p <- cbind(arrange(summarise(group_by(pl_p, region), roc_auc=mean(roc_auc)), roc_auc), factor(1:length(levels(pl_p$region))))
# colnames(data_p)[3] <- "order"
# plp_p <- left_join(pl_p, data_p, by=c("region"))

# %%
mean_br_p = pl_p.groupby('region').agg(np.mean)
# %Rpush mean_br_p

# %%
pylab.rcParams['figure.figsize'] = 5, 5  # that's default image size for this interactive session
br_auc_pplot = sns.regplot(mean_br_p.base_rate, mean_br_p.roc_auc, ci=None)
tooltip = mpld3.plugins.PointLabelTooltip(br_auc_pplot.collections[0], labels=list(mean_br_p.index))
fig = plt.gcf()
mpld3.plugins.connect(fig, tooltip)

# %%
# %%R
# print(summary(rlm(roc_auc~base_rate, data=mean_br_p))$coefficients)
# Out:
#                  Value Std. Error     t value
# (Intercept) 0.59156289 0.01342708 44.05745503
# base_rate   0.01647575 0.56155111  0.02933971

# %% [markdown]
# There does seem to be a slight relationship between base rate such that as base rate increases, discriminability decreases. However, it doesn't seem very robust and there are many expections - not driving the effects

# %% [markdown]
# ### Feature importances

# %%
mean_fis_p= pd.DataFrame(np.array([np.round(p_clf.feature_importances.mean(axis=0).mean(axis=0)*100000000000000, 5), p_clf.feature_names]).T, columns=['mean_fi', 'topic_name'])
mean_fis_p = pd.merge(mean_fis_p, word_keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-628d5e7ea6f5> in <module>()
# ----> 1 mean_fis_p= pd.DataFrame(np.array([np.round(p_clf.feature_importances.mean(axis=0).mean(axis=0)*100000000000000, 5), p_clf.feature_names]).T, columns=['mean_fi', 'topic_name'])
#       2 mean_fis_p = pd.merge(mean_fis_p, word_keys)
#
# NameError: name 'p_clf' is not defined

# %%
p_fi = pd.DataFrame(p_clf.feature_importances.mean(axis=0))

# Melt feature importances, and add top_words for each feeature
p_fi['region'] = range(1, p_fi.shape[0] + 1)
p_fis_melt = pd.melt(p_fi, var_name='topic_order', value_name='importance', id_vars=['region'])

top_words = pd.read_csv("../data/unprocessed/abstract_topics_filtered/top_words_80.csv")
keys = pd.merge(pd.DataFrame(np.array([range(0, 80), p_clf.feature_names]).T, columns=['topic_order', 'topic_name']), top_words)
keys.topic_order = keys.topic_order.astype('int')

p_fis_melt= pd.merge(p_fis_melt, keys)
p_fis_melt['abs_imp'] = np.abs(p_fis_melt['importance'])

p_fis_melt = pd.merge(
    p_fis_melt, pd.DataFrame(np.array([p_clf.class_score.mean(axis=1), range(1, p_clf.class_score.shape[0] + 1)]).T, columns=['roc_auc', 'region']))
# %Rpush p_fis_melt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-176-966270424a65> in <module>()
# ----> 1 p_fi = pd.DataFrame(p_clf.feature_importances.mean(axis=0))
#       2
#       3 # Melt feature importances, and add top_words for each feeature
#       4 p_fi['region'] = range(1, p_fi.shape[0] + 1)
#       5 p_fis_melt = pd.melt(p_fi, var_name='topic_order', value_name='importance', id_vars=['region'])
#
# NameError: name 'p_clf' is not defined

# %%
sh_acc = pd.DataFrame(np.array([range(0, p_clf.mask_num), list(mc.accuracy_stats(p_clf, method='shannons')), list(mc.importance_stats(p_clf, method='shannons'))]).T, columns=['region', 'shannons_acc', 'shannons_imp'])

# %%
p_fis_melt = pd.merge(p_fis_melt, sh_acc, on='region')

# %%
p_fis_melt[p_fis_melt.region == 23]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-b76b4fc4cc1f> in <module>()
# ----> 1 p_fis_melt[p_fis_melt.region == 23]
#
# NameError: name 'p_fis_melt' is not defined

# %%
# categories = np.unique(p_fis_melt['topic_name'])
# colors = np.linspace(0, 1, len(categories))
# colordict = dict(zip(categories, colors))
# p_fis_melt["Color"] = p_fis_melt['topic_name'].apply(lambda x: colordict[x])

# pylab.rcParams['figure.figsize'] = 10, 5  # that's default image size for this interactive session
# sns.set_style("white")
# scatter_p = plt.scatter(p_fis_melt.roc_auc, p_fis_melt.importance, c=p_fis_melt.Color, cmap=cm.Set1, s=50, alpha=0.8)
# fig = plt.gcf()
# tooltip = mpld3.plugins.PointLabelTooltip(scatter_p, labels=list(zip(p_fis_melt.region.values, p_fis_melt.top_words.values)))
# mpld3.plugins.connect(fig, tooltip)

# %% [markdown]
# Bottom three regions are 'junk' - 1, 18, 21
# Then 19 - high BR mPFC
#
# Top are highly specific regions - amygdala

# %% [markdown]
# ###Diversity of accuracy

# %%
# sns.lmplot('shannons_acc', 'roc_auc', data=p_fis_melt)

# %% [markdown]
# ### Comparing one vs all and pairwise classification performance

# %% [markdown]
# #### Classification accuracy

# %%
stats.pearsonr(mean_br.roc_auc, mean_br_p.roc_auc)
# Out:
# (0.76131197162104525, 1.0334553463339689e-06)

# %%
# pylab.rcParams['figure.figsize'] = 5, 5  # that's default image size for this interactive session
# o_v_p = sns.regplot(mean_br.roc_auc, mean_br_p.roc_auc, ci=None)
# tooltip = mpld3.plugins.PointLabelTooltip(o_v_p.collections[0], labels=list(mean_br_p.index))
# fig = plt.gcf()
# mpld3.plugins.connect(fig, tooltip)

# %% [markdown]
# Amygdala improves most w/ pairwise
#     - As do speech regions, motor regions, lateral occipital
# Most decreased
#     - Sprawly regions
#     - Visual cortex
#     -  mPFC, insula

# %% [markdown]
# Similar, but not exactly the same class accuracy

# %% [markdown]
# #### Feature importances

# %%
p_fi = p_clf.feature_importances.mean(axis=0)
o_fi = o_clf.feature_importances

# %%
fi_cors = np.array([stats.pearsonr(region, o_fi[n])[0] for n, region in enumerate(p_fi)])

# %%
fi_cors.mean()
# Out:
# 0.75499168342479739

# %%
o_p_fi = pd.DataFrame(np.array([mean_br.roc_auc.values, mean_br_p.roc_auc.values, fi_cors]).T, columns=['ova', 'pairwise', 'ficorr'])
# %Rpush o_p_fi

# %%
# %%R
# ggplot(o_p_fi, aes(ova, pairwise, size=ficorr)) + geom_point() + geom_smooth(method=lm)

# %% [markdown]
# This relationship does not seem to be mediated by how correlated the weights are

# %%
stats.pearsonr(o_clf_mean_corr, p_clf.class_score.mean(axis=0))
# Out:
# (-0.56115777758383911, 0.0012548268746778259)

# %%
mean_corr_score = pd.DataFrame(np.array([o_clf_mean_corr, p_clf.class_score.mean(axis=0)]).T, columns=['corr', 'score'])

# %%
# o_v_fi_p = sns.regplot(mean_corr_score['corr'], mean_corr_score['score'], ci=None)
# tooltip = mpld3.plugins.PointLabelTooltip(o_v_fi_p.collections[0], labels=list(mean_corr_score.index + 1))
# fig = plt.gcf()
# mpld3.plugins.connect(fig, tooltip)

# %% [markdown]
# ## Coactivation

# %%
from neurosynth.analysis.reduce import average_within_regions
import itertools

# %%
a_coef = np.corrcoef(average_within_regions(dataset, '../masks/ward/30.nii.gz'))
a_coef = tools.mask_diagonal(np.ma.masked_array(a_coef))

# %%
a_coef.mean()
# Out:
# 0.26732581395746846

# %%
# sns.corrplot(a_coef.T, sig_stars=False, sig_corr=False, annot=False)

# %%
stats.pearsonr(o_clf.class_score, a_coef.mean(axis=0))
# Out:
# (-0.0079317188455638732, 0.96681886817499807)

# %%
labels = list(itertools.permutations(range(0, p_clf.mask_num), 2))

# %%
cs = p_clf.class_score.flatten()
cs = cs[cs != 0]

# %%
a_coef_f = a_coef.data.flatten()
a_coef_f = a_coef_f[a_coef_f != 1]

# %%
cs_coef = pd.DataFrame([cs, a_coef_f, labels, list(zip(*labels)[0])]).T
cs_coef.columns = ["class_score", "coactivation", "label", "region"]

# %%
cs_coef.coactivation = cs_coef.coactivation.astype('float16')

# %%
cs_coef_o = cs_coef.groupby('region').agg(np.mean).reset_index()[['coactivation', 'region']]

# %%
cs_coef_o = pd.merge(cs_coef_o, mean_br)

# %%
stats.pearsonr(cs_coef.class_score, cs_coef.coactivation)
# Out:
# (-0.45965487093386243, 1.0769023991418137e-46)

# %%
# cs_coef_p = sns.regplot(cs_coef['coactivation'], cs_coef['class_score'], ci=None)
# tooltip = mpld3.plugins.PointLabelTooltip(cs_coef_p.collections[0], labels=list(cs_coef.label))
# fig = plt.gcf()
# mpld3.plugins.connect(fig, tooltip)

# %%
cs_coef.class_score = cs_coef.class_score.astype('float32')
# %Rpush cs_coef

# %%
cs_coef.class_score.max()
# Out:
# 0.72732997

# %%
# %%R -w 800
# cs_coef = mutate(group_by(cs_coef, region), mean_score = mean(class_score))
# ggplot(cs_coef, aes(mean_score, class_score)) + geom_point() +
#  stat_summary(fun.y=mean, geom='point', size=7) + stat_summary(fun.y=mean, geom='point', size=7, shape=1, color="black") + theme_bw() + theme(legend.position='none')

# %%
# Mean roc_auc for each region
cs_coef_pmean = cs_coef.groupby('region').agg(np.mean).class_score.mean()

# %%
# Mean SD of roc_auc for each region
cs_coef.groupby('region').agg(lambda x: x.class_score.std()).class_score.mean()
# Out:
# 0.049826473492263636

# %% [markdown]
# ### Region specific analysis

# %%
tools.make_mask_map_4d(p_clf.class_score, p_clf.mask_img, '../results/ward_30_Pairwise_RidgeClassifier_roc_DM_abs_topics_filt_tn_50/class_score_4d')

# %%
def get_region_fis(n, comparison = None):
    n = n - 1
    p_fi = pd.DataFrame(p_clf.feature_importances[n])

    # Melt feature importances, and add top_words for each feeature
    p_fi['region'] = range(1, p_fi.shape[0] + 1)
    p_fis_melt = pd.melt(p_fi, var_name='topic_order', value_name='importance', id_vars=['region'])

    top_words = pd.read_csv("../data/unprocessed/abstract_topics_filtered/top_words_80.csv")
    keys = pd.merge(pd.DataFrame(np.array([range(0, 80), p_clf.feature_names]).T, columns=['topic_order', 'topic_name']), top_words)
    keys.topic_order = keys.topic_order.astype('int')

    p_fis_melt= pd.merge(p_fis_melt, keys)

    p_fis_melt = pd.merge(
        p_fis_melt, pd.DataFrame(np.array([p_clf.class_score[n], range(1, p_clf.class_score.shape[0] + 1)]).T, columns=['roc_auc', 'region']))
    p_fis_melt['abs_imp'] = np.abs(p_fis_melt['importance'])

    p_fis_melt =  p_fis_melt[p_fis_melt['region'] != n + 1]
    if comparison is not None:
        p_fis_melt = p_fis_melt[p_fis_melt['region'] == comparison]
        
    p_fis_melt['importance'] = p_fis_melt['importance'] * - 1
    return p_fis_melt

# %% [markdown]
# Region 1: Medial hippocampus
# - Lowest accuracy is against parahippocampus - 0.5 (15)
# - Next lowest pcc/acc - 0.54 (22)
#
# Does well:
# - pre-SMA: 0.7 (9)
# - Lateral occipital - 0.7 (23)

# %%
p_clf.class_score[0].max()
# Out:
# 0.72732994585498401

# %%
hp = p_clf.class_score[0]

# %%
np.where(hp == hp.min())
# Out:
# (array([14]),)

# %%
## Topic weights for hippocampus (1)
# vs Parahipp - 15
get_region_fis(1, 15).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name                  top_words  \
# 1177      15           57    0.043732    topic60     spatial location space
# 1123      15            3    0.035448    topic11         body visual images
# 1159      15           39    0.030422    topic44     sleep switching switch
# 1195      15           75    0.029468    topic77  emotional emotion neutral
# 1133      15           13    0.027390    topic20  memory encoding retrieval
# 1189      15           69    0.026942    topic71      object objects visual
# 1167      15           47    0.023995    topic51      motor imagery primary
# 1140      15           20    0.023699    topic27          asd autism social
# 1198      15           78   -0.022251     topic8     reward decision choice
# 1168      15           48   -0.021185    topic52     speech auditory sounds
#
#        roc_auc   abs_imp
# 1177  0.503623  0.043732
# 1123  0.503623  0.035448
# 1159  0.503623  0.030422
# 1195  0.503623  0.029468
# ...

# %%
## Topic weights for hippocampus (1)
# pcc/acc = 22
get_region_fis(1, 22).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name                    top_words  \
# 1755      22           75    0.160590    topic77    emotional emotion neutral
# 1707      22           27    0.085308    topic33  fear conditioning responses
# 1693      22           13    0.067927    topic20    memory encoding retrieval
# 1691      22           11   -0.061614    topic19      wm integrity fractional
# 1748      22           68    0.051517    topic70          anxiety threat fear
# 1715      22           35    0.043658    topic40               ad disease mci
# 1724      22           44   -0.043463    topic49               memory wm load
# 1733      22           53   -0.042824    topic57  condition conditions active
# 1717      22           37   -0.042249    topic42      language fluency verbal
# 1732      22           52   -0.041824    topic56  inhibition conflict control
#
#        roc_auc   abs_imp
# 1755  0.548314  0.160590
# 1707  0.548314  0.085308
# 1693  0.548314  0.067927
# ...

# %%
## Topic weights for hippocampus (1)
# presma - 9
get_region_fis(1, 9).sort('abs_imp', ascending=False)[0:10]
# Out:
#      region  topic_order  importance topic_name  \
# 715       9           75    0.156529    topic77
# 649       9            9   -0.149372    topic17
# 653       9           13    0.125540    topic20
# 692       9           52   -0.103681    topic56
# 687       9           47   -0.093524    topic51
# 672       9           32   -0.088483    topic38
# 650       9           10   -0.078036    topic18
# 675       9           35    0.070780    topic40
# 657       9           17   -0.068274    topic24
# 677       9           37   -0.067984    topic42
#
#                          top_words   roc_auc   abs_imp
# 715      emotional emotion neutral  0.706952  0.156529
# 649       motor movements movement  0.706952  0.149372
# 653      memory encoding retrieval  0.706952  0.125540
# 692    inhibition conflict control  0.706952  0.103681
# 687          motor imagery primary  0.706952  0.093524
# 672  cognitive performance control  0.706952  0.088483
# ...

# %%
## Topic weights for hippocampus (23)
# presma - 23
get_region_fis(1, 23).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name  \
# 1835      23           75    0.197116    topic77
# 1769      23            9   -0.136341    topic17
# 1772      23           12   -0.101710     topic2
# 1773      23           13    0.095519    topic20
# 1792      23           32   -0.087331    topic38
# 1783      23           23   -0.084563     topic3
# 1812      23           52   -0.075887    topic56
# 1807      23           47   -0.075288    topic51
# 1787      23           27    0.074173    topic33
# 1804      23           44   -0.070658    topic49
#
#                           top_words   roc_auc   abs_imp
# 1835      emotional emotion neutral  0.705207  0.197116
# 1769       motor movements movement  0.705207  0.136341
# 1772   attention attentional target  0.705207  0.101710
# 1773      memory encoding retrieval  0.705207  0.095519
# 1792  cognitive performance control  0.705207  0.087331
# 1783     action actions observation  0.705207  0.084563
# ...

# %%
## Hippocampus vs best discriminated region (primary motor)
# 
get_region_fis(1, 18).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name  \
# 1435      18           75    0.162034    topic77
# 1369      18            9   -0.143830    topic17
# 1373      18           13    0.119630    topic20
# 1397      18           37   -0.108233    topic42
# 1383      18           23   -0.107410     topic3
# 1412      18           52   -0.082636    topic56
# 1395      18           35    0.081835    topic40
# 1431      18           71    0.081659    topic73
# 1387      18           27    0.078838    topic33
# 1364      18            4   -0.075194    topic12
#
#                           top_words  roc_auc   abs_imp
# 1435      emotional emotion neutral  0.72733  0.162034
# 1369       motor movements movement  0.72733  0.143830
# 1373      memory encoding retrieval  0.72733  0.119630
# 1397        language fluency verbal  0.72733  0.108233
# 1383     action actions observation  0.72733  0.107410
# 1412    inhibition conflict control  0.72733  0.082636
# ...

# %%
## Topic weights for supramarginal gyrus / auditory / language?
# left vlpfc ()
get_region_fis(7, 17).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name  \
# 1328      17           48    0.096530    topic52
# 1293      17           13   -0.073383    topic20
# 1331      17           51    0.065772    topic55
# 1351      17           71    0.046857    topic73
# 1326      17           46   -0.042492    topic50
# 1357      17           77   -0.039089    topic79
# 1358      17           78   -0.038830     topic8
# 1281      17            1   -0.037064     topic1
# 1291      17           11    0.036749    topic19
# 1344      17           64   -0.035231    topic67
#
#                               top_words   roc_auc   abs_imp
# 1328             speech auditory sounds  0.503481  0.096530
# 1293          memory encoding retrieval  0.503481  0.073383
# 1331            visual auditory sensory  0.503481  0.065772
# 1351                  volume gray voxel  0.503481  0.046857
# 1326  reasoning autobiographical events  0.503481  0.042492
# 1357            lesions damage controls  0.503481  0.039089
# ...

# %%
## Topic weights for supramarginal gyrus / auditory / language?
# Paracingulate (dorsal)
get_region_fis(7, 29).sort('abs_imp', ascending=False)[0:10]
# Out:
#       region  topic_order  importance topic_name  \
# 2288      29           48    0.102212    topic52
# 2272      29           32   -0.089145    topic38
# 2291      29           51    0.071515    topic55
# 2254      29           14    0.071277    topic21
# 2311      29           71    0.062408    topic73
# 2258      29           18   -0.061192    topic25
# 2314      29           74   -0.059412    topic76
# 2290      29           50   -0.057610    topic54
# 2284      29           44   -0.052495    topic49
# 2292      29           52   -0.051861    topic56
#
#                              top_words   roc_auc   abs_imp
# 2288            speech auditory sounds  0.535928  0.102212
# 2272     cognitive performance control  0.535928  0.089145
# 2291           visual auditory sensory  0.535928  0.071515
# 2254  sentences comprehension sentence  0.535928  0.071277
# 2311                 volume gray voxel  0.535928  0.062408
# 2258   perceptual color discrimination  0.535928  0.061192
# ...

# %%
## Topic weights for supramarginal gyrus / auditory / language?
# vmpfc
get_region_fis(7, 10).sort('abs_imp', ascending=False)[0:10]
# Out:
#      region  topic_order  importance topic_name  \
# 768      10           48    0.179632    topic52
# 742      10           22   -0.140817    topic29
# 771      10           51    0.115691    topic55
# 798      10           78   -0.108426     topic8
# 734      10           14    0.103832    topic21
# 757      10           37    0.099490    topic42
# 749      10           29    0.099218    topic35
# 727      10            7   -0.081447    topic15
# 733      10           13   -0.070336    topic20
# 720      10            0   -0.067329     topic0
#
#                             top_words  roc_auc   abs_imp
# 768            speech auditory sounds    0.693  0.179632
# 742           network resting default    0.693  0.140817
# 771           visual auditory sensory    0.693  0.115691
# 798            reward decision choice    0.693  0.108426
# 734  sentences comprehension sentence    0.693  0.103832
# 757           language fluency verbal    0.693  0.099490
# ...

# %%
## Topic weights for supramarginal gyrus / auditory / language?
# vmpfc
get_region_fis(7, 6).sort('abs_imp', ascending=False)[0:10]
# Out:
#      region  topic_order  importance topic_name  \
# 448       6           48    0.185517    topic52
# 409       6            9   -0.119495    topic17
# 414       6           14    0.118811    topic21
# 404       6            4   -0.089382    topic12
# 410       6           10   -0.082855    topic18
# 429       6           29    0.078426    topic35
# 463       6           63    0.071284    topic66
# 451       6           51    0.068424    topic55
# 423       6           23   -0.064937     topic3
# 469       6           69   -0.062528    topic71
#
#                             top_words   roc_auc   abs_imp
# 448            speech auditory sounds  0.610075  0.185517
# 409          motor movements movement  0.610075  0.119495
# 414  sentences comprehension sentence  0.610075  0.118811
# 404     stimulation somatosensory tms  0.610075  0.089382
# 410          pain painful stimulation  0.610075  0.082855
# 429                reading words word  0.610075  0.078426
# ...

# %%
## Left IFG
## VS Postcentral Gyrus (L)
get_region_fis(17, 24).sort('abs_imp', ascending=False)[0:8]
# Out:
#       region  topic_order  importance topic_name  \
# 1849      24            9   -0.206146    topic17
# 1854      24           14    0.139678    topic21
# 1844      24            4   -0.102510    topic12
# 1887      24           47   -0.097345    topic51
# 1915      24           75    0.087720    topic77
# 1877      24           37    0.085074    topic42
# 1869      24           29    0.082953    topic35
# 1857      24           17   -0.070749    topic24
#
#                              top_words   roc_auc   abs_imp
# 1849          motor movements movement  0.694984  0.206146
# 1854  sentences comprehension sentence  0.694984  0.139678
# 1844     stimulation somatosensory tms  0.694984  0.102510
# 1887             motor imagery primary  0.694984  0.097345
# 1915         emotional emotion neutral  0.694984  0.087720
# 1877           language fluency verbal  0.694984  0.085074
# 1869                reading words word  0.694984  0.082953
# ...

# %%
## Left IFG
## VS mHipp/Amyg (L)
get_region_fis(17,1).sort('abs_imp', ascending=False)[0:8]
# Out:
#     region  topic_order  importance topic_name  \
# 14       1           14    0.158179    topic21
# 29       1           29    0.134418    topic35
# 37       1           37    0.130751    topic42
# 75       1           75   -0.090091    topic77
# 48       1           48    0.074004    topic52
# 27       1           27   -0.057471    topic33
# 71       1           71   -0.053982    topic73
# 63       1           63    0.053763    topic66
#
#                            top_words   roc_auc   abs_imp
# 14  sentences comprehension sentence  0.632964  0.158179
# 29                reading words word  0.632964  0.134418
# 37           language fluency verbal  0.632964  0.130751
# 75         emotional emotion neutral  0.632964  0.090091
# 48            speech auditory sounds  0.632964  0.074004
# 27       fear conditioning responses  0.632964  0.057471
# 71                 volume gray voxel  0.632964  0.053982
# 63       semantic priming repetition  0.632964  0.053763
#
# ...

# %%
## Left IFG
## VS Right IFG
get_region_fis(17, 28).sort('abs_imp', ascending=False)[0:8]
# Out:
#       region  topic_order  importance topic_name  \
# 2174      28           14    0.139682    topic21
# 2189      28           29    0.130507    topic35
# 2197      28           37    0.095379    topic42
# 2173      28           13    0.079175    topic20
# 2187      28           27   -0.076102    topic33
# 2170      28           10   -0.073981    topic18
# 2210      28           50    0.065363    topic54
# 2200      28           40   -0.062758    topic45
#
#                              top_words   roc_auc   abs_imp
# 2174  sentences comprehension sentence  0.598084  0.139682
# 2189                reading words word  0.598084  0.130507
# 2197           language fluency verbal  0.598084  0.095379
# 2173         memory encoding retrieval  0.598084  0.079175
# 2187       fear conditioning responses  0.598084  0.076102
# 2170          pain painful stimulation  0.598084  0.073981
# 2210        mental arithmetic rotation  0.598084  0.065363
# ...

# %%
## Left IFG
## VS region immediately dorsal (MFG)
get_region_fis(17, 4).sort('abs_imp', ascending=False)[0:8]
# Out:
#      region  topic_order  importance topic_name  \
# 272       4           32   -0.085837    topic38
# 315       4           75    0.071685    topic77
# 252       4           12   -0.057815     topic2
# 254       4           14    0.057242    topic21
# 308       4           68    0.045369    topic70
# 280       4           40   -0.044495    topic45
# 317       4           77    0.042184    topic79
# 251       4           11   -0.038797    topic19
#
#                             top_words  roc_auc   abs_imp
# 272     cognitive performance control  0.52878  0.085837
# 315         emotional emotion neutral  0.52878  0.071685
# 252      attention attentional target  0.52878  0.057815
# 254  sentences comprehension sentence  0.52878  0.057242
# 308               anxiety threat fear  0.52878  0.045369
# 280                     eye gaze eyes  0.52878  0.044495
# 317           lesions damage controls  0.52878  0.042184
# 251           wm integrity fractional  0.52878  0.038797
#
# ...

# %%
### INTERESTINGLY EMTION IS NOT A TOP WORD FOR IFG OVERALL
p_fis_melt[p_fis_melt['region'] == 21].sort('abs_imp', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-9087842cbc51> in <module>()
#       1 ### INTERESTINGLY EMTION IS NOT A TOP WORD FOR IFG OVERALL
# ----> 2 p_fis_melt[p_fis_melt['region'] == 21].sort('abs_imp', ascending=False)
#
# NameError: name 'p_fis_melt' is not defined

# %%
## Left IFG
## VS more dorsal MFG
get_region_fis(17, 13).sort('abs_imp', ascending=False)[0:8]
# Out:
#       region  topic_order  importance topic_name  \
# 974       13           14    0.067224    topic21
# 989       13           29    0.046700    topic35
# 997       13           37    0.045610    topic42
# 982       13           22   -0.039645    topic29
# 1023      13           63    0.036982    topic66
# 1009      13           49    0.033375    topic53
# 1037      13           77    0.028801    topic79
# 972       13           12   -0.027187     topic2
#
#                              top_words   roc_auc   abs_imp
# 974   sentences comprehension sentence  0.502107  0.067224
# 989                 reading words word  0.502107  0.046700
# 997            language fluency verbal  0.502107  0.045610
# 982            network resting default  0.502107  0.039645
# 1023       semantic priming repetition  0.502107  0.036982
# 1009            risk genetic relatives  0.502107  0.033375
# 1037           lesions damage controls  0.502107  0.028801
# ...

# %%
## Left IFG
## VS OFC / vast PFC area
get_region_fis(17, 12).sort('abs_imp', ascending=False)[0:8]
# Out:
#      region  topic_order  importance topic_name  \
# 894      12           14    0.176048    topic21
# 909      12           29    0.098151    topic35
# 928      12           48    0.079231    topic52
# 917      12           37    0.076610    topic42
# 912      12           32   -0.051120    topic38
# 903      12           23    0.047650     topic3
# 933      12           53   -0.046602    topic57
# 902      12           22   -0.045177    topic29
#
#                             top_words   roc_auc   abs_imp
# 894  sentences comprehension sentence  0.573848  0.176048
# 909                reading words word  0.573848  0.098151
# 928            speech auditory sounds  0.573848  0.079231
# 917           language fluency verbal  0.573848  0.076610
# 912     cognitive performance control  0.573848  0.051120
# 903        action actions observation  0.573848  0.047650
# 933       condition conditions active  0.573848  0.046602
# 902           network resting default  0.573848  0.045177
#
# ...

# %%
## Left IFG
## VS Operculum anteior of it
get_region_fis(17, 3).sort('abs_imp', ascending=False)[0:8]
# Out:
#      region  topic_order  importance topic_name  \
# 174       3           14    0.151215    topic21
# 189       3           29    0.091426    topic35
# 170       3           10   -0.063738    topic18
# 183       3           23    0.063698     topic3
# 171       3           11   -0.050683    topic19
# 237       3           77    0.049509    topic79
# 173       3           13    0.047774    topic20
# 187       3           27   -0.045775    topic33
#
#                             top_words   roc_auc   abs_imp
# 174  sentences comprehension sentence  0.564053  0.151215
# 189                reading words word  0.564053  0.091426
# 170          pain painful stimulation  0.564053  0.063738
# 183        action actions observation  0.564053  0.063698
# 171           wm integrity fractional  0.564053  0.050683
# 237           lesions damage controls  0.564053  0.049509
# 173         memory encoding retrieval  0.564053  0.047774
# 187       fear conditioning responses  0.564053  0.045775
#
# ...

# %%
mean_imps_p = p_clf.feature_importances.mean(axis=0)
imp_corrs = []
for n, row in enumerate(mean_imps_p):
    res = [stats.pearsonr(row, column)[0] for column in p_clf.feature_importances[n]]
    imp_corrs.append(res)
imp_corrs = np.array(results)

# %%
stats.pearsonr(imp_corrs.flatten(), p_clf.class_score.flatten())
# Out:
# (nan, 1.0)

# %%
imp_corrs = np.ma.masked_array(imp_corrs,  mask = np.isnan(imp_corrs))

# %%
stats.pearsonr([x for x in imp_corrs.flatten().data if str(x) != 'nan'], [x for x in p_clf.class_score.flatten().data if x != 0.0])
# Out:
# (-0.40102063269338506, 6.0324859682771305e-35)

# %% [markdown]
# len([x for x in p_clf.class_score.flatten().data if x != 0.0])
