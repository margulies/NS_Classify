# %%
from IPython.html import widgets
# %matplotlib inline

import numpy as np
from base.classifiers import OnevsallContinuous
from base.classifiers import PairwiseContinuous

import pandas as pd
from scipy import stats
import seaborn as sns
import mpld3
import matplotlib.pyplot as plt
import matplotlib.cm as cm
mpld3.enable_notebook()
import scipy
import glob

from neurosynth.base.dataset import Dataset
dataset = Dataset.load("../data/datasets/abs_80topics_filt_jul.pkl")
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
pairwise = PairwiseContinuous.load('../results/ward_f60_Pairwise_Ridge_abs_topics60_filt/classifier.pkl')
ova = OnevsallContinuous.load('../results/ward_f60_Ridge_abs_topics60_filt/classifier.pkl')
pairwise_rz = PairwiseContinuous.load('../results/ward_f60_Pairwise_Ridge_rz_abs_topics60_filt/classifier.pkl')

# %%
fi_coef_ova = np.corrcoef(ova.feature_importances)

# %%
pairwise.scores.shape
# Out:
# (60, 60)

# %%
fi_coef_ova.shape
# Out:
# (60, 60)

# %%
stats.pearsonr(pairwise.scores.data.flatten(), fi_coef_ova.flatten())
# Out:
# (-0.57865360848658476, 6.3882688007273178e-321)

# %%
stats.pearsonr(pairwise_rz.scores.data.flatten(), fi_coef_ova.flatten())
# Out:
# (-0.69276610771821878, 0.0)

# %%
sns.regplot(pairwise_rz.scores.data.flatten(), fi_coef_ova.flatten())

# %%
from neurosynth.analysis.reduce import average_within_regions
import itertools
a_coef = np.corrcoef(average_within_regions(dataset, pairwise.mask_img))

# %%
stats.pearsonr(pairwise.scores.data.flatten(), a_coef.flatten())
# Out:
# (-0.49665209437938851, 1.3517389393235439e-223)

# %%
stats.pearsonr(pairwise_rz.scores.data.flatten(), a_coef.flatten())
# Out:
# (-0.63328837884371081, 0.0)

# %%
stats.pearsonr(fi_coef_ova.flatten(), a_coef.flatten())
# Out:
# (0.87238489015925691, 0.0)

# %%
pairwise_rz.feature_importances.data[0].shape
# Out:
# (60, 60)
