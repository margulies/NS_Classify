# %%
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
# %load_ext rmagic
# %matplotlib inline
from base.classifiers import OnevsallClassifier
from base.classifiers import PairwiseClassifier
import numpy as np
from base import plotting
import base.classifiers.pairwise as pw
import base.classifiers.onevsall as oa
import base.classifiers
import glob
import pandas as pd
from ggplot import *
from base import tools
from scipy import stats
import itertools
import seaborn as sns
import mpld3
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module multiprocessing was already imported from /usr/local/Cellar/python/2.7.3/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/__init__.pyc, but /usr/local/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import make_scorer

# %%
clf = OnevsallClassifier.load("../results/ward_30_OvA_RidgeClassifier_DM_hard0_roc_abs_topics_filt_tn_50/classifier.pkl")

# %%
scorer = make_scorer(roc_auc_score)
classifier = RidgeClassifier()

# %%
results = []
for reg in range(0, 30):
    X = clf.c_data[reg][0]
    y = clf.c_data[reg][1]
    fis = clf.feature_importances[reg]

    for i in range(1, 81):
        X_1 =  X[:, np.abs(fis).argsort()[::-1][0:i]]
        results.append([cross_val_score(classifier, X_1, y, cv=4, scoring=scorer).mean(), i, reg])
results = pd.DataFrame(results, columns=['score', 'num_features', 'region'])

# %%
fis = clf.feature_importances[20]
np.abs(fis).argsort()[::-1][5]
# Out:
# 77

# %%
X = clf.c_data[20][0]
y = clf.c_data[20][1]

# %%
X_1 = X[:, np.abs(fis).argsort()[::-1][4:80]]

# %%
cross_val_score(classifier, X_1, y, cv=4, scoring=scorer).mean()
# Out:
# 0.5879862549735293

# %%
# %Rpush results

# %%
# %%R
# library(dplyr)
# ms <- results %.%
#     group_by(num_features) %.%
#     summarise(score=mean(score))
#
# (0.5242132 - 0.5) / (max(ms$score) - 0.5)
# Out:
# [1] 0.2550575

# %%
# %%R -w 450 -h 390
# library(ggplot2)
# ggplot(results, aes(num_features, score)) + stat_summary(fun.y=mean, geom="point") + coord_cartesian(ylim=c(0.5, 0.6)) + theme_bw() + ylab("Discriminability (area under ROC)" ) + xlab("") + theme(axis.title.y = element_text(size = 13, vjust = 0.2))

# %%
(results.groupby('num_features').agg(np.mean).max())  - ((results.groupby('num_features').agg(np.mean).max() - 0.5) * .1)
# Out:
# score      0.585439
# region    13.100000
# dtype: float64

# %%
results.groupby('num_features').agg(np.mean) > 0.58439
# Out:
#               score region
# num_features
# 1             False   True
# 2             False   True
# 3             False   True
# 4             False   True
# 5             False   True
# 6             False   True
# 7             False   True
# 8             False   True
# 9             False   True
# 10            False   True
# 11            False   True
# 12            False   True
# 13            False   True
# 14            False   True
# 15            False   True
# 16            False   True
# 17            False   True
# 18            False   True
# 19             True   True
# 20             True   True
# 21             True   True
# 22             True   True
# 23             True   True
# 24             True   True
# 25             True   True
# 26             True   True
# 27             True   True
# 28             True   True
# 29             True   True
# 30             True   True
# 31             True   True
# 32             True   True
# 33             True   True
# 34             True   True
# 35             True   True
# 36             True   True
# 37             True   True
# 38             True   True
# 39             True   True
# 40             True   True
# 41             True   True
# 42             True   True
# 43             True   True
# 44             True   True
# 45             True   True
# 46             True   True
# 47             True   True
# 48             True   True
# 49             True   True
# 50             True   True
# 51             True   True
# 52             True   True
# 53             True   True
# 54             True   True
# 55             True   True
# 56             True   True
# 57             True   True
# 58             True   True
# 59             True   True
# 60             True   True
#                 ...    ...
#
# [80 rows x 2 columns]

# %%
fis = pd.DataFrame(clf.feature_importances)
fis['region'] = range(0, 30)
fis_melt = pd.melt(fis, var_name='topic_order', value_name='importance', id_vars=['region'])

# %%
top_words = pd.read_csv("../data/unprocessed/abstract_topics_filtered/top_words_80-july.csv")
keys = pd.merge(pd.DataFrame(np.array([range(0, 80), clf.feature_names]).T, columns=['topic_order', 'topic_name']), top_words)
keys.topic_order = keys.topic_order.astype('int')

# %%
fis_melt
# Out:
#     region  topic_order  importance
# 0        0            0   -0.008468
# 1        1            0   -0.009724
# 2        2            0   -0.010405
# 3        3            0   -0.018569
# 4        4            0   -0.007704
# 5        5            0   -0.020413
# 6        6            0   -0.034828
# 7        7            0    0.011238
# 8        8            0   -0.011421
# 9        9            0    0.012088
# 10      10            0   -0.007148
# 11      11            0   -0.013800
# 12      12            0   -0.020275
# 13      13            0   -0.018235
# 14      14            0    0.008176
# 15      15            0    0.012653
# 16      16            0   -0.007234
# 17      17            0   -0.032849
# 18      18            0   -0.003366
# 19      19            0    0.006634
# 20      20            0   -0.014529
# 21      21            0    0.014853
# 22      22            0   -0.025811
# 23      23            0   -0.011661
# 24      24            0   -0.022093
# 25      25            0   -0.013267
# 26      26            0    0.001050
# 27      27            0   -0.020890
# 28      28            0   -0.003904
# 29      29            0   -0.006808
# 30       0            1   -0.006770
# 31       1            1   -0.003967
# 32       2            1   -0.015051
# 33       3            1   -0.005944
# 34       4            1    0.008539
# 35       5            1   -0.036628
# 36       6            1   -0.020570
# 37       7            1   -0.022734
# 38       8            1   -0.009175
# 39       9            1   -0.023489
# 40      10            1   -0.015833
# 41      11            1   -0.023672
# 42      12            1   -0.026206
# 43      13            1   -0.014999
# 44      14            1   -0.023929
# 45      15            1   -0.013906
# 46      16            1   -0.011630
# 47      17            1   -0.020153
# 48      18            1   -0.006886
# 49      19            1   -0.030504
# 50      20            1   -0.000064
# 51      21            1   -0.019154
# 52      22            1   -0.011809
# 53      23            1   -0.020034
# 54      24            1   -0.000302
# 55      25            1   -0.013522
# 56      26            1   -0.013552
# 57      27            1   -0.008460
# 58      28            1   -0.020612
# 59      29            1   -0.038052
#        ...          ...         ...
#
# [2400 rows x 3 columns]

# %%
fis_melt = pd.merge(fis_melt, keys)
fis_melt['abs_imp'] = np.abs(fis_melt['importance'])

# %%
fis_melt[fis_melt.groupby('region')['abs_imp'].rank(ascending=False) < 6].sort(['region', 'abs_imp'])
# Out:
#       region  topic_order  importance topic_name  \
# 1440       0           48    0.073403    topic52
# 2280       0           76   -0.073927    topic78
# 2100       0           70    0.098755    topic72
# 1320       0           44    0.106111    topic49
# 420        0           14    0.112462    topic21
# 511        1           17    0.063793    topic24
# 691        1           23   -0.071749     topic3
# 1411       1           47   -0.073655    topic51
# 1561       1           52   -0.083369    topic56
# 901        1           30    0.085701    topic36
# 2282       2           76   -0.063163    topic78
# 2132       2           71    0.066621    topic73
# 182        2            6    0.077300    topic14
# 1892       2           63   -0.080712    topic66
# 92         2            3    0.089536    topic11
# 2313       3           77    0.078441    topic79
# 183        3            6    0.081498    topic14
# 2133       3           71    0.092335    topic73
# 423        3           14    0.095477    topic21
# 753        3           25    0.104871    topic31
# 424        4           14    0.051488    topic21
# 994        4           33    0.056048    topic39
# 1954       4           65   -0.056850    topic68
# 1204       4           40    0.069049    topic45
# 94         4            3    0.089962    topic11
# 2285       5           76   -0.066731    topic78
# 1475       5           49    0.076798    topic53
# 95         5            3    0.080850    topic11
# 1565       5           52    0.083132    topic56
# 995        5           33    0.102906    topic39
# 2316       6           77    0.069571    topic79
# 1416       6           47   -0.077857    topic51
# 756        6           25    0.094782    topic31
# 486        6           16    0.099088    topic23
# 1566       6           52    0.186598    topic56
# 1417       7           47   -0.039444    topic51
# 1477       7           49    0.042365    topic53
# 907        7           30   -0.048244    topic36
# 997        7           33    0.065152    topic39
# 2287       7           76   -0.077743    topic78
# 1628       8           54   -0.060557    topic58
# 2138       8           71    0.062938    topic73
# 98         8            3    0.068574    topic11
# 188        8            6    0.097974    topic14
# 998        8           33    0.129159    topic39
# 699        9           23   -0.066694     topic3
# 129        9            4    0.071985    topic12
# 1029       9           34    0.073903     topic4
# 999        9           33   -0.078798    topic39
# 1269       9           42    0.133580    topic47
# 2290      10           76   -0.067104    topic78
# 1900      10           63   -0.077080    topic66
# 1000      10           33    0.088856    topic39
# 1570      10           52    0.101384    topic56
# 100       10            3    0.110866    topic11
# 701       11           23   -0.068475     topic3
# 2141      11           71    0.070629    topic73
# 431       11           14    0.080193    topic21
# 2351      11           78   -0.081585     topic8
# 191       11            6    0.083800    topic14
#          ...          ...         ...        ...
#
#                              top_words   abs_imp
# 1440          fear threat conditioning  0.073403
# 2280        standard individual images  0.073927
# 2100      emotional facial expressions  0.098755
# 1320        emotional negative emotion  0.106111
# 420          memory encoding retrieval  0.112462
# 511         object objects recognition  0.063793
# 691      stimulation tms somatosensory  0.071749
# 1411         human humans organization  0.073655
# 1561            speech auditory sounds  0.083369
# 901         visual stimulus perceptual  0.085701
# 2282        standard individual images  0.063163
# 2132                    memory wm load  0.066621
# 182        control inhibition conflict  0.077300
# 1892            frequency source alpha  0.080712
# 92            pain painful stimulation  0.089536
# 2313                reading words word  0.078441
# 183        control inhibition conflict  0.081498
# 2133                    memory wm load  0.092335
# 423          memory encoding retrieval  0.095477
# 753   sentences comprehension sentence  0.104871
# 424          memory encoding retrieval  0.051488
# 994           motor movement movements  0.056048
# 1954      attention attentional visual  0.056850
# 1204      reward anticipation monetary  0.069049
# 94            pain painful stimulation  0.089962
# 2285        standard individual images  0.066731
# 1475        action actions observation  0.076798
# 95            pain painful stimulation  0.080850
# 1565            speech auditory sounds  0.083132
# 995           motor movement movements  0.102906
# 2316                reading words word  0.069571
# 1416         human humans organization  0.077857
# 756   sentences comprehension sentence  0.094782
# 486            visual auditory sensory  0.099088
# 1566            speech auditory sounds  0.186598
# 1417         human humans organization  0.039444
# 1477        action actions observation  0.042365
# 907         visual stimulus perceptual  0.048244
# 997           motor movement movements  0.065152
# 2287        standard individual images  0.077743
# 1628                 volume gray voxel  0.060557
# 2138                    memory wm load  0.062938
# 98            pain painful stimulation  0.068574
# 188        control inhibition conflict  0.097974
# 998           motor movement movements  0.129159
# 699      stimulation tms somatosensory  0.066694
# 129              social empathy people  0.071985
# 1029           memory retrieval events  0.073903
# 999           motor movement movements  0.078798
# 1269           network resting default  0.133580
# 2290        standard individual images  0.067104
# 1900            frequency source alpha  0.077080
# 1000          motor movement movements  0.088856
# 1570            speech auditory sounds  0.101384
# 100           pain painful stimulation  0.110866
# 701      stimulation tms somatosensory  0.068475
# 2141                    memory wm load  0.070629
# 431          memory encoding retrieval  0.080193
# 2351           wm fractional integrity  0.081585
# 191        control inhibition conflict  0.083800
#                                    ...       ...
#
# [150 rows x 6 columns]

# %%
def minimum_percent(region, percent=.1):
    max = region['score'].max() 
    labeled_rows = (region['score'] > (max - ((max - 0.5) * percent)))
    return region[labeled_rows]['num_features'].min()

def minimum_fixed(region, fixed=.01):
    labeled_rows = (region['score'] > (region['score'].max() - fixed))
    return region[labeled_rows]['num_features'].min()

# %%
ten_percent = results.groupby('region').apply(minimum_percent, percent=0.1)
ten_percent_r = results.groupby('region').agg(np.mean)

# %%
tools.make_mask_map(t, '../masks/Ward/30.nii.gz', '../results/ward_30_OvA_RidgeClassifier_DM_hard0_roc_abs_topics_filt_tn_50/mv_10percent.nii')

# %%
t = np.array(ten_percent).astype('float64')

# %%
t = t / 100

# %%
clf.class_score.dtype
# Out:
# dtype('float64')

# %%
t.astype('float64')
# Out:
# array([ 18.,  28.,  24.,  19.,  21.,  27.,  11.,  16.,  27.,  22.,  31.,
#         17.,  24.,  22.,  14.,  29.,   9.,  19.,  18.,  19.,  24.,   9.,
#         24.,   2.,  30.,  24.,  23.,   3.,  19.,  24.])

# %%
stats.pearsonr(results.groupby('region').head(1).score,ten_percent_r.score)
# Out:
# (0.48366048271024281, 0.0067725562357102125)

# %%
stats.pearsonr(ten_percent,ten_percent_r.score)
# Out:
# (0.39986415044004658, 0.028572038274793595)

# %%
sns.regplot(ten_percent,ten_percent_r.score)

# %%
ten_percent_r
# Out:
#            score  num_features
# region
# 0       0.629559          40.5
# 1       0.608648          40.5
# 2       0.599611          40.5
# 3       0.614077          40.5
# 4       0.556470          40.5
# 5       0.585014          40.5
# 6       0.620279          40.5
# 7       0.506460          40.5
# 8       0.605306          40.5
# 9       0.609424          40.5
# 10      0.597363          40.5
# 11      0.618404          40.5
# 12      0.574971          40.5
# 13      0.643430          40.5
# 14      0.560167          40.5
# 15      0.550361          40.5
# 16      0.573514          40.5
# 17      0.622730          40.5
# 18      0.541427          40.5
# 19      0.586119          40.5
# 20      0.583100          40.5
# 21      0.539190          40.5
# 22      0.645203          40.5
# 23      0.570498          40.5
# 24      0.595990          40.5
# 25      0.582008          40.5
# 26      0.618289          40.5
# 27      0.501649          40.5
# 28      0.533184          40.5
# 29      0.618595          40.5
#
# [30 rows x 2 columns]

# %%
np.array(ten_percent)
# Out:
# array([18, 28, 24, 19, 21, 27, 11, 16, 27, 22, 31, 17, 24, 22, 14, 29,  9,
#        19, 18, 19, 24,  9, 24,  2, 30, 24, 23,  3, 19, 24])

# %%
ten_percent
# Out:
# region
# 0         18
# 1         28
# 2         24
# 3         19
# 4         21
# 5         27
# 6         11
# 7         16
# 8         27
# 9         22
# 10        31
# 11        17
# 12        24
# 13        22
# 14        14
# 15        29
# 16         9
# 17        19
# 18        18
# 19        19
# 20        24
# 21         9
# 22        24
# 23         2
# 24        30
# 25        24
# 26        23
# 27         3
# 28        19
# 29        24
# dtype: int64

# %%
# %Rpush results
results.to_csv("multivariate.csv", index=False)

# %%
# %%R -w 900 -h 425
# ggplot(subset(results, region %in% c(20, 23)), aes(num_features, score)) + geom_point() +  facet_grid(.~region) + theme_bw() + xlab("Number of features") + ylab("Discriminability (Area under ROC)") + coord_cartesian(ylim=c(0.5, 0.64)) + ylab("") + theme(axis.text.y = element_blank(), axis.title.x = element_text(size = 13, hjust=.21, vjust=0))
